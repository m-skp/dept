# %%
from dept import *
# Out:
# current location: c:\Users\souku\OneDrive\Documents\code_repository\dept

# %%
import boto3

# read config file
aws_config = read_file('configs/aws.json')
aws_session = boto3.Session(aws_config)

# instantiate S3 connector
s3 = aws_session.resource('s3')

# print awailable S3 buckets
print(*s3.buckets.all())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       8 s3 = aws_session.resource('s3')
#      10 # print awailable S3 buckets
# ---> 11 print(*s3.buckets.all())
#
# File c:\Users\souku\miniconda3\envs\dept\lib\site-packages\boto3\resources\collection.py:81, in ResourceCollection.__iter__(self)
#      78 limit = self._params.get('limit', None)
#      80 count = 0
# ---> 81 for page in self.pages():
#      82     for item in page:
#      83         yield item
#
# File c:\Users\souku\miniconda3\envs\dept\lib\site-packages\boto3\resources\collection.py:166, in ResourceCollection.pages(self)
#     159 else:
#     160     logger.debug(
#     161         'Calling %s:%s with %r',
#     162         self._parent.meta.service_name,
#     163         self._py_operation_name,
#     164         params,
#     165     )
# ...
